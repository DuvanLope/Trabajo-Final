# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("diabetes_risk_dataset.csv")
df.head(20)
# Out:
#     Patient_ID  age  gender   bmi  blood_pressure  fasting_glucose_level  \
# 0            1   77  Female  33.8             154                     93
# 1            2   54    Male  19.2             123                     94
# 2            3   25    Male  33.7             141                    150
# 3            4   23  Female  32.8             140                    145
# 4            5   70    Male  33.7             165                     90
# 5            6   57  Female  33.0             145                     88
# 6            7   22  Female  31.9             140                    120
# 7            8   39  Female  28.8             123                     88
# 8            9   79  Female  41.7             177                     83
# 9           10   60    Male  35.8             145                    146
# 10          11   48  Female  31.8             134                    101
# 11          12   67    Male  33.8             144                     94
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Patient_ID                  6000 non-null   int64
#  1   age                         6000 non-null   int64
#  2   gender                      6000 non-null   object
#  3   bmi                         6000 non-null   float64
#  4   blood_pressure              6000 non-null   int64
#  5   fasting_glucose_level       6000 non-null   int64
#  6   insulin_level               6000 non-null   float64
#  7   HbA1c_level                 6000 non-null   float64
#  8   cholesterol_level           6000 non-null   int64
#  9   triglycerides_level         6000 non-null   int64
#  10  physical_activity_level     6000 non-null   object
#  11  daily_calorie_intake        6000 non-null   int64
#  12  sugar_intake_grams_per_day  6000 non-null   float64
# ...

# %%
df.describe().T
# Out:
#                              count         mean          std     min      25%  \
# Patient_ID                  6000.0  3000.500000  1732.195139     1.0  1500.75
# age                         6000.0    52.230667    18.757508    20.0    36.00
# bmi                         6000.0    32.939667     7.510155    16.0    26.90
# blood_pressure              6000.0   144.482500    17.867248    91.0   132.00
# fasting_glucose_level       6000.0   106.105500    31.213994    60.0    87.00
# insulin_level               6000.0    15.080333     9.245581     2.0     7.10
# HbA1c_level                 6000.0     5.784583     0.956614     4.1     5.20
# cholesterol_level           6000.0   217.490667    24.888595   139.0   200.00
# triglycerides_level         6000.0   177.351500    51.897606    50.0   137.00
# daily_calorie_intake        6000.0  2479.547000   548.410642  1200.0  2055.00
# sugar_intake_grams_per_day  6000.0    66.555733    39.576891     0.0    35.10
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID                    0
# age                           0
# gender                        0
# bmi                           0
# blood_pressure                0
# fasting_glucose_level         0
# insulin_level                 0
# HbA1c_level                   0
# cholesterol_level             0
# triglycerides_level           0
# physical_activity_level       0
# daily_calorie_intake          0
# sugar_intake_grams_per_day    0
# sleep_hours                   0
# stress_level                  0
# family_history_diabetes       0
# waist_circumference_cm        0
# diabetes_risk_score           0
# diabetes_risk_category        0
# dtype: int64

# %%
df.isnull().sum()/len(df) * 100
# Out:
# Patient_ID                    0.0
# age                           0.0
# gender                        0.0
# bmi                           0.0
# blood_pressure                0.0
# fasting_glucose_level         0.0
# insulin_level                 0.0
# HbA1c_level                   0.0
# cholesterol_level             0.0
# triglycerides_level           0.0
# physical_activity_level       0.0
# daily_calorie_intake          0.0
# sugar_intake_grams_per_day    0.0
# sleep_hours                   0.0
# stress_level                  0.0
# family_history_diabetes       0.0
# waist_circumference_cm        0.0
# diabetes_risk_score           0.0
# diabetes_risk_category        0.0
# dtype: float64

# %%
print("Duplicados Antes", df.duplicated().sum())

df = df.drop_duplicates()

print("Duplicados Después", df.duplicated().sum())
# Out:
# Duplicados Antes 0
# Duplicados Después 0

# %%
df.to_csv('diabetes_risk_dataset.csv', index=False)

# %%
print(df.shape)
# Out:
# (6000, 19)

# %%
df.describe(include="object").T
# Out:
#                         count unique       top  freq
# gender                   6000      2    Female  3051
# physical_activity_level  6000      3       Low  3181
# family_history_diabetes  6000      2        No  4838
# diabetes_risk_category   6000      3  Low Risk  2602

# %%
print(df['diabetes_risk_category'].value_counts())
# Out:
# diabetes_risk_category
# Low Risk       2602
# High Risk      2245
# Prediabetes    1153
# Name: count, dtype: int64

# %%
print(df['physical_activity_level'].value_counts())
# Out:
# physical_activity_level
# Low         3181
# Moderate    1539
# High        1280
# Name: count, dtype: int64

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

print("Columnas Numéricas:", list(numeric_cols))
print("Columnas Categóricas:", list(categorical_cols))
# Out:
# Columnas Numéricas: ['Patient_ID', 'age', 'bmi', 'blood_pressure', 'fasting_glucose_level', 'insulin_level', 'HbA1c_level', 'cholesterol_level', 'triglycerides_level', 'daily_calorie_intake', 'sugar_intake_grams_per_day', 'sleep_hours', 'stress_level', 'waist_circumference_cm', 'diabetes_risk_score']
# Columnas Categóricas: ['gender', 'physical_activity_level', 'family_history_diabetes', 'diabetes_risk_category']

# %%
for col in df.columns:
    if "date" in col.lower() or "time" in col.lower():
        df[col] = pd.to_datetime(df[col], errors='coerce')

    df.head()

# %%
df = df.dropna()
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Patient_ID                  6000 non-null   int64
#  1   age                         6000 non-null   int64
#  2   gender                      6000 non-null   object
#  3   bmi                         6000 non-null   float64
#  4   blood_pressure              6000 non-null   int64
#  5   fasting_glucose_level       6000 non-null   int64
#  6   insulin_level               6000 non-null   float64
#  7   HbA1c_level                 6000 non-null   float64
#  8   cholesterol_level           6000 non-null   int64
#  9   triglycerides_level         6000 non-null   int64
#  10  physical_activity_level     6000 non-null   object
#  11  daily_calorie_intake        6000 non-null   int64
#  12  sugar_intake_grams_per_day  6000 non-null   float64
# ...

# %%
df.info()
df.rename(columns={"Patient_ID":"ID_Paciente","age":"Edad","gender":"Genero","bmi":"IMC","blood_pressure":"Presion_Arterial","fasting_glucose_level":"Glucosa","insulin_level":"Insulina","HbA1c_level":"HbA1c","cholesterol_level":"Colesterol","triglycerides_level":"Trigliceridos","physical_activity_level":"Nivel_Actividad_Fisica","daily_calorie_intake":"Ingesta_Calorica_Diaria","sugar_intake_grams_per_day":"Ingesta_Azucar_Diaria","sleep_hours":"Horas_Sueño","stress_level":"Nivel_Estres","family_history_diabetes":"Historial_Familiar_Diabetes","waist_circumference_cm":"Circunferencia_Cintura_cm","diabetes_risk_score":"Puntuacion_Riesgo_Diabetes","diabetes_risk_category":"Categoria_Riesgo_Diabetes"},inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Patient_ID                  6000 non-null   int64
#  1   age                         6000 non-null   int64
#  2   gender                      6000 non-null   object
#  3   bmi                         6000 non-null   float64
#  4   blood_pressure              6000 non-null   int64
#  5   fasting_glucose_level       6000 non-null   int64
#  6   insulin_level               6000 non-null   float64
#  7   HbA1c_level                 6000 non-null   float64
#  8   cholesterol_level           6000 non-null   int64
#  9   triglycerides_level         6000 non-null   int64
#  10  physical_activity_level     6000 non-null   object
#  11  daily_calorie_intake        6000 non-null   int64
#  12  sugar_intake_grams_per_day  6000 non-null   float64
# ...

# %%
df['Edad'].unique()
# Out:
# array([77, 54, 25, 23, 70, 57, 22, 39, 79, 60, 48, 67, 24, 58, 51, 46, 53,
#        62, 84, 26, 28, 45, 52, 21, 61, 31, 78, 30, 33, 38, 68, 44, 74, 34,
#        42, 27, 40, 36, 56, 32, 50, 35, 43, 47, 66, 76, 81, 41, 20, 65, 64,
#        49, 75, 72, 63, 37, 69, 59, 73, 80, 82, 55, 83, 71, 29])

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_paciente                  6000 non-null   int64
#  1   edad                         6000 non-null   int64
#  2   genero                       6000 non-null   object
#  3   imc                          6000 non-null   float64
#  4   presion_arterial             6000 non-null   int64
#  5   glucosa                      6000 non-null   int64
#  6   insulina                     6000 non-null   float64
#  7   hba1c                        6000 non-null   float64
#  8   colesterol                   6000 non-null   int64
#  9   trigliceridos                6000 non-null   int64
#  10  nivel_actividad_fisica       6000 non-null   object
#  11  ingesta_calorica_diaria      6000 non-null   int64
#  12  ingesta_azucar_diaria        6000 non-null   float64
# ...

# %%
df["genero"].head(2)
# Out:
# 0    Female
# 1      Male
# Name: genero, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import urllib.request

# %%
edad_promedio = df.groupby('categoria_riesgo_diabetes')['edad'].mean()

plt.figure(figsize=(10,5))
plt.bar(edad_promedio.index, edad_promedio.values)

plt.title("Edad promedio según categoría de riesgo de diabetes")
plt.xlabel("Categoría de riesgo")
plt.ylabel("Edad promedio")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
cuenta_genero=df["genero"].value_counts()
plt.figure(figsize=(10,5))
plt.bar(cuenta_genero.index,cuenta_genero.values, color="blue")
plt.xticks(rotation=90)
plt.title("Genero con mas riesgo de diabetes")
plt.show()

# %%
url = "diabetes_risk_dataset.csv"
Diabetes = pd.read_csv(url)
imagen = "diabetesimg.png"
imagen1 = plt.imread(imagen)
plt.imshow(imagen1)
plt.axis("off")
plt.show()
